# %% [markdown]
# ## 0328 : 한국어 처리 패키지
# - 한국어 정보 처리를 위한 파이썬 패키지이다.
# - 참조 사이트 : https://wikidocs.net/22647

# %% [markdown]
# ## 한국어 말뭉치¶
# KoNLPy에서는 대한민국 헌법 말뭉치인 kolaw와 국회법안 말뭉치인 kobill을 제공한다. 각 말뭉치가 포함하는 파일의 이름은 fields 메서드로 알 수 있고 open 메서드로 해당 파일의 텍스트를 읽어들인다.

# %%
# !pip install konlpy
# Out:
# ...
#      ---------------------------------------- 0.0/19.4 MB ? eta -:--:--
#       --------------------------------------- 0.3/19.4 MB 8.6 MB/s eta 0:00:03
#      - -------------------------------------- 0.7/19.4 MB 9.2 MB/s eta 0:00:03
#      -- ------------------------------------- 1.1/19.4 MB 9.0 MB/s eta 0:00:03
#      --- ------------------------------------ 1.6/19.4 MB 9.3 MB/s eta 0:00:02
#      ---- ----------------------------------- 2.1/19.4 MB 9.5 MB/s eta 0:00:02
#      ----- ---------------------------------- 2.6/19.4 MB 9.7 MB/s eta 0:00:02
#      ------ --------------------------------- 3.1/19.4 MB 9.9 MB/s eta 0:00:02
#      ------- -------------------------------- 3.7/19.4 MB 10.2 MB/s eta 0:00:02
#      -------- ------------------------------- 4.2/19.4 MB 10.2 MB/s eta 0:00:02
#      --------- ------------------------------ 4.7/19.4 MB 10.4 MB/s eta 0:00:02
#      ---------- ----------------------------- 5.2/19.4 MB 10.3 MB/s eta 0:00:02
# ...

# %%
import warnings
warnings.simplefilter("ignore")

import konlpy
konlpy.__version__
# Out:
# '0.6.0'

# %%
from konlpy.tag import Okt

okt = Okt()
tokens = okt.morphs("나는 자연어 처리를 배운다")
print(tokens)
# Out:
# ['나', '는', '자연어', '처리', '를', '배운다']

# %%
word_to_index = {word : index for index, word in enumerate(tokens)}
print('단어 집합 :', word_to_index)
# Out:
# 단어 집합 : {'나': 0, '는': 1, '자연어': 2, '처리': 3, '를': 4, '배운다': 5}

# %%
def one_hot_encoding(word, word_to_index):
    one_hot_vector = [0]*(len(word_to_index))
    index = word_to_index[word]
    one_hot_vector[index] =1
    return one_hot_vector

# %%
- '자연어'라는 단어의 원-핫-벡터를 얻어봅시다.

# %%
one_hot_encoding("자연어", word_to_index)
# Out:
# [0, 0, 1, 0, 0, 0]

# %% [markdown]
# - '자연어'는 정수 2이므로 원-핫 벡터는 인덱스 2의 값이 1이며 나머지 값은 0인 벡터가 나온다.

# %%
# 2. 케라스를 이용한 원핫 인코딩
- 파이썬으로 위에서는 직접 작성했으나, keras는 원-핫 인코딩을 수행하는 유용한 도구 to_categorical()을 지원한다.
- keras로 실행해 보자.

# %%
text ="나랑 점심 먹으러 갈래 점심 메뉴는 햄버거 먹자 햄버거 최고야"

# %%
# !pip install tensorflow
# Out:
# ...
#      ---------------------------------------- 0.0/272.9 MB ? eta -:--:--
#      ---------------------------------------- 0.2/272.9 MB 4.8 MB/s eta 0:00:57
#      ---------------------------------------- 0.3/272.9 MB 3.8 MB/s eta 0:01:13
#      ---------------------------------------- 0.6/272.9 MB 4.6 MB/s eta 0:01:00
#      ---------------------------------------- 0.9/272.9 MB 5.1 MB/s eta 0:00:54
#      ---------------------------------------- 1.3/272.9 MB 6.1 MB/s eta 0:00:45
#      ---------------------------------------- 1.8/272.9 MB 6.8 MB/s eta 0:00:40
#      ---------------------------------------- 2.2/272.9 MB 7.1 MB/s eta 0:00:39
#      ---------------------------------------- 2.6/272.9 MB 7.3 MB/s eta 0:00:38
#      ---------------------------------------- 3.0/272.9 MB 7.3 MB/s eta 0:00:37
#       --------------------------------------- 3.4/272.9 MB 7.6 MB/s eta 0:00:36
#       --------------------------------------- 4.0/272.9 MB 7.9 MB/s eta 0:00:35
# ...

# %%
# !pip install tensorflow
# Out:
# ...
#   Using cached tensorflow-2.12.0-cp311-cp311-win_amd64.whl (1.9 kB)
# ...
#   Using cached tensorflow_intel-2.12.0-cp311-cp311-win_amd64.whl (272.9 MB)
# ...
#   Using cached absl_py-1.4.0-py3-none-any.whl (126 kB)
# ...
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# ...
#   Using cached flatbuffers-23.3.3-py2.py3-none-any.whl (26 kB)
# ...
#   Using cached gast-0.4.0-py3-none-any.whl (9.8 kB)
# ...
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# ...
#   Using cached h5py-3.8.0-cp311-cp311-win_amd64.whl (2.6 MB)
# ...
#   Using cached jax-0.4.7.tar.gz (1.2 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      ---------------------------------------- 0.0/24.4 MB ? eta -:--:--
#       --------------------------------------- 0.3/24.4 MB 10.6 MB/s eta 0:00:03
#      - -------------------------------------- 1.0/24.4 MB 12.1 MB/s eta 0:00:02
#      -- ------------------------------------- 1.5/24.4 MB 12.1 MB/s eta 0:00:02
# ...

# %%
import tensorflow as tf
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 import tensorflow as tf
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.utils import to_categorical

text = "나랑 점심 먹으러 갈래 점심 메뉴는 햄버거 갈래 갈래 햄버거 최고야"

tokenizer = Tokenizer()
tokenizer.fit_on_texts([text])
print('단어 집합 :',tokenizer.word_index)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 from tensorflow.keras.preprocessing.text import Tokenizer
#       2 from tensorflow.keras.utils import to_categorical
#       4 text = "나랑 점심 먹으러 갈래 점심 메뉴는 햄버거 갈래 갈래 햄버거 최고야"
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
sub_text = "점심 먹으러 갈래 메뉴는 햄버거 최고야"
encoded = tokenizer.texts_to_sequences([sub_text])[0]
print(encoded)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 2
#       1 sub_text = "점심 먹으러 갈래 메뉴는 햄버거 최고야"
# ----> 2 encoded = tokenizer.texts_to_sequences([sub_text])[0]
#       3 print(encoded)
#
# NameError: name 'tokenizer' is not defined
